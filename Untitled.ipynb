# %%
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt

# function that returns dy/dt
def model(y,t):
    k = 0.3
    dydt = -k * y
    return dydt

# initial condition
y0 = 3

# time points
t = np.linspace(0,20)

# solve ODE
y = odeint(model,y0,t)

# plot results
plt.plot(t,y)
plt.xlabel('time')
plt.ylabel('y(t)')
plt.show()

# %%
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt

# function that returns dy/dt
def model(y,t,k):
    dydt = -k * y
    return dydt

# initial condition
y0 = 1

# time points
t = np.linspace(0,10,21)

# solve ODEs
k = 0.1
y1 = odeint(model,y0,t,args=(k,))
k = 0.2
y2 = odeint(model,y0,t,args=(k,))
k = 0.5
y3 = odeint(model,y0,t,args=(k,))
k = -0.1
y4 = odeint(model,y0,t,args=(k,))

# plot results
plt.plot(t,y1,'r-',linewidth=2,label='k=0.1')
plt.plot(t,y2,'b--',linewidth=2,label='k=0.2')
plt.plot(t,y3,'g:',linewidth=2,label='k=0.5')
plt.plot(t,y4,'black',linewidth=2,label='k=-0.1')
plt.xlabel('time')
plt.ylabel('y(t)')
plt.legend()
plt.show()

# %%
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt

# function that returns dy/dt
def model(y,t):
    k = 1
    dydt = (-1)*y+1 
    return dydt

# initial condition
y0 = 0

# time points
t1 = np.linspace(0,5,21)
t2 = np.linspace(0,-1,21)

# solve ODE
y1 = odeint(model,y0,t1)
y2 = odeint(model,y0,t2)

#t2 = np.flip(t2)
#y2 = np.flip(y2)

t = np.concatenate([t2[::-1][:-1],t1])
y = np.concatenate([y2[::-1][:-1],y1])
#t = t2 + t1
#y = y2 + y1
print(t)


#s = odeint(model,y0,[1.,2.])
#print(s)

# plot results
plt.plot(t,y)
plt.xlabel('time')
plt.ylabel('y(t)')
plt.show()
# Out:
# [-1.   -0.95 -0.9  -0.85 -0.8  -0.75 -0.7  -0.65 -0.6  -0.55 -0.5  -0.45
#  -0.4  -0.35 -0.3  -0.25 -0.2  -0.15 -0.1  -0.05  0.    0.25  0.5   0.75
#   1.    1.25  1.5   1.75  2.    2.25  2.5   2.75  3.    3.25  3.5   3.75
#   4.    4.25  4.5   4.75  5.  ]

# %%
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt

# function that returns dy/dt
def model(y,t):
    if t <= 10.0:
        u = 0
    elif t <= 20.0:
        u = 2
    elif t <= 30:
        u = 1
    elif t <= 50:
        u = 3
    else:
        u = 0
    dydt = (-y+u)/5.0
    return dydt

# initial condition
y0 = 1

# time points
t = np.linspace(0,80)

# solve ODE
y = odeint(model,y0,t)



# plot results
plt.plot(t,y)
plt.xlabel('time')
plt.ylabel('y(t)')
plt.show()

# %%
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt
import math

# function that returns dy/dt
def modelX(x,t):
    dxdt = 3 * math.exp(-t)
    return dxdt

def modelY(y,t):
    dydt = 3 - y
    return dydt

# initial condition
x0 = 0
y0 = 0


# time points
t = np.linspace(0,20)

# solve ODE
x = odeint(modelX,x0,t)
y = odeint(modelY,y0,t)

# plot results
plt.plot(t,x,'g')
plt.xlabel('time')
plt.ylabel('x(t)')
plt.show()

plt.plot(t,y,'r')
plt.xlabel('time')
plt.ylabel('y(t)')
plt.show()

# %%
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt

# function that returns dz/dt
def model(z,t,u):
    x = z[0]
    y = z[1]
    dxdt = (-x + u)/2.0
    dydt = (-y + x)/5.0
    dzdt = [dxdt,dydt]
    return dzdt

# initial condition
z0 = [0,0]

# number of time points
n = 401

# time points
t = np.linspace(0,40,n)

# step input
u = np.zeros(n)
# change to 2.0 at time = 5.0
u[51:] = 2.0

# store solution
x = np.empty_like(t)
y = np.empty_like(t)
# record initial conditions
x[0] = z0[0]
y[0] = z0[1]

# solve ODE
for i in range(1,n):
    # span for next time step
    tspan = [t[i-1],t[i]]
    # solve for next step
    z = odeint(model,z0,t,args=(u[i],))
    # store solution for plotting
    x[i] = z[1][0]
    y[i] = z[1][1]
    # next initial condition
    z0 = z[1]

# plot results
plt.plot(t,u,'g:',label='u(t)')
plt.plot(t,x,'b-',label='x(t)')
plt.plot(t,y,'r--',label='y(t)')
plt.ylabel('values')
plt.xlabel('time')
plt.legend(loc='best')
plt.show()

# %%
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt

def model(y,t):
    dydt = y
    return dydt
def model1(y,t):
    dydt = -y
    return dydt

y0 = 1

t1 = np.linspace(0,2,11)
y1 = odeint(model,y0,t1)
t2 = np.linspace(0,-2,11)
y2 = odeint(model,y0,t2)

t = np.append(t2[::-1][:-1],t1)
y = np.append(y2[::-1][:-1],y1)

plt.plot(t,y,'b-')

y0 = 2

t1 = np.linspace(0,2,11)
y1 = odeint(model,y0,t1)
t2 = np.linspace(0,-2,11)
y2 = odeint(model,y0,t2)

t = np.append(t2[::-1][:-1],t1)
y = np.append(y2[::-1][:-1],y1)

plt.plot(t,y,'k-')



y0 = 1

t1 = np.linspace(0,2,11)
y1 = odeint(model1,y0,t1)
t2 = np.linspace(0,-2,11)
y2 = odeint(model1,y0,t2)

t = np.append(t2[::-1][:-1],t1)
y = np.append(y2[::-1][:-1],y1)

plt.plot(t,y,'g-')



y0 = 4

t1 = np.linspace(0,2,11)
y1 = odeint(model,y0,t1)
t2 = np.linspace(0,-2,11)
y2 = odeint(model,y0,t2)

t = np.append(t2[::-1][:-1],t1)
y = np.append(y2[::-1][:-1],y1)

plt.plot(t,y,'r-')
plt.ylabel('value')
plt.xlabel('time')
plt.show()

# %%
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt

# function that returns dy/dt
def model(y,t):
    k = 0
    dydt = 1/(t+16)
    return dydt

y0 = 0
t0 = 0
a = 15

t = np.linspace(-a,a,a*20+1)
y = np.zeros(a*20+1)



n0 = t0*10 + a*10

y[n0] = y0

for i in range(n0+1,a*20+1):
    p = odeint(model,y[i-1],[t[i-1],t[i]])
    y[i] = p[1]

for i in range(n0-1,-1,-1):
    p = odeint(model,y[i+1],[t[i+1],t[i]])
    y[i] = p[1]
    #print(p)
    
plt.plot(t,y,'r-')
plt.grid()
plt.show()

# %%
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt

# function that returns dy/dt
def model(y,t):
    k = 0
    dydt = 2*t
    return dydt

y0 = 0
t0 = 0
a = -29
b = 1

t = np.linspace(a,b,(b-a)*10+1)
y = np.zeros((b-a)*10+1)



n0 = t0*10 - a*10

y[n0] = y0

for i in range(n0+1,(b-a)*10+1):
    p = odeint(model,y[i-1],[t[i-1],t[i]])
    y[i] = p[1]

for i in range(n0-1,-1,-1):
    p = odeint(model,y[i+1],[t[i+1],t[i]])
    y[i] = p[1]
    #print(p)
    
plt.plot(t,y,'r-')
plt.grid()
plt.show()

# %%
for i in range(1015,105):
    print(str(i)+'.jpg,')

# %%
i = 69
j = 1
lst = ['bamboo','characters','dots']
lstpos = 0
count = 0
while(lstpos<3 and i <10):
    print(str(i)+'.jpg,'+lst[lstpos]+'-'+str(j))
    count+=1
    i+=1
    if count == 4:
        j+=1
        count = 0
    if j == 10:
        j = 1
        lstpos+=1

# %%
i = 907
j = 1
lst = ['dots','bamboo','characters']
lstpos = 0
count = 0
while(j<10 and i < 150):
    print(str(i)+'.jpg,'+lst[lstpos]+'-'+str(j))
    count+=1
    i+=1
    if count == 4:
        lstpos +=1
        count = 0
    if lstpos == 3:
        j += 1
        lstpos = 0

# %%
i = 807
j = 1
lst = ['bamboo','dots','characters']
lstpos = 0
count = 0
while(lstpos<3 and i <100):
    print(str(i)+'.jpg,'+lst[lstpos]+'-'+str(j))
    j+=1
    i+=1
    if j == 10:
        j = 1
        count += 1
    if count == 4:
        lstpos +=1
        count = 0

# %%
from __future__ import print_function
import itertools

def my_coroutine():
  # Бесконечный счетчик
  counter = itertools.count()
  while True:
    y = (yield next(counter))
    if y:
      # Меняем начало отсчета
      counter = itertools.count(y)
myiterator = my_coroutine()
for item in myiterator:
  print(item, end=" ")
  if item == 1:
    # Отправляем число в генератор
    myiterator.send(4)
  elif item == 10:
    myiterator.close()
## 0 1 5 6
# Out:
# 0 1 5 6 7 8 9 10

# %%
class A:
    def __init__(self):
        pass
    
    @classmethod
    def __someFunction(cls):
        print('hi')
    
    @classmethod
    def AnotherFunction(cls):
        print('hello')
        
class B(A):
    def __init(self):
        pass
    @classmethod
    def __someFunction(cls):
        print('hihi')
        
B._B__someFunction()
# Out:
# hihi

# %%
class A:
    def __init__(self,a):
        self.a = a
        
class C(A):
    def __init__(self,c):
        self.c = c
        super().__init__(c)
        
instanceC = C(2)
instanceC.c
# Out:
# 2

# %%
import sys

foo = []

# 2 ссылки, одна от переменной foo и одна от getrefcount
print(sys.getrefcount(foo))
f = foo
print(sys.getrefcount(foo))
# Out:
# 2
# 3

# %%
def createInstance():
    if 1==2:
        return False
    return True 
 
class CustomizeInstance():
    _instance = None
    def __new__(cls, a, b):
        if not cls._instance:
            instance = super(CustomizeInstance, cls).__new__(cls)
            instance.a = a
            instance.b = b
            cls._instance = instance
            return instance
 
    def __init__(self, a, b):
        pass
    
a = CustomizeInstance(1,2)
a.b
b = CustomizeInstance(1,2)
c.a
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-85672264ccc1> in <module>
#      20 a.b
#      21 b = CustomizeInstance(1,2)
# ---> 22 c.a
#
# NameError: name 'c' is not defined
